# %% [markdown]
# # Paso 1: Lectura de archivos para el año 2015

# %%
# Importación de librerias
import pandas as pd

# Definición de la clase
class ImportClass:
    
    # Función inicial o constructor
    def __init__(self):
        # lectura de los archivos
        
## PASO 1: Lectura del archivo estadística_idc_2011_2015_2019 y separación en Dataframes por año
##------------------------------------------------------------------------------------------------------------------------##
        self.df_estadistica_idc_2015 = pd.read_excel(r'estadística_idc_2011_2015_2019.xlsx', 
                                                    sheet_name='2015', dtype={
                                                                               'dd': str,
                                                                               'mm': str,
                                                                               'Departamento': str,
                                                                               'Municipio': str,
                                                                               'Total': int
                                                                           }) 
##------------------------------------------------------------------------------------------------------------------------##
## PASO 2: Lectura del archivo delitos_electorales_spoa_2011_2015_2019
        self.df_delitos_electorales_spoa_2011_2015_2019 = pd.read_csv(r'delitos_electorales_spoa_2011_2015_2019.csv', sep=';', encoding='UTF-8-SIG') 
    
##------------------------------------------------------------------------------------------------------------------------##
## PASO 3: Lectura del archivo trashumancia_2015
        self.df_trashumancia_2015 = pd.read_excel(r'trashumancia_2015.xlsx', 
                                                    sheet_name='Trash2015', dtype={
                                                                               'Orden': str,
                                                                               'Departamento': str,
                                                                               'Municipio': str,
                                                                               'Trashumantes': int
                                                                           })
##------------------------------------------------------------------------------------------------------------------------##
## PASO 4: Lectura del archivo divipole_autoridades_locales_2015
        self.df_divipole_autoridades_locales_2015 = pd.read_excel(r'divipole_autoridades_locales_2015.xlsx', 
                                                    sheet_name='Base', dtype={
                                                                               'dd': str,
                                                                               'mm': str,
                                                                               'zz': str,
                                                                               'pp': str,
                                                                               'Departamento': str,
                                                                               'Municipio': str,
                                                                               'Puesto': str,
                                                                               'Mujeres': int,
                                                                               'Hombres': int,
                                                                               'Total': int,
                                                                               'Mesas': int,
                                                                               'Dirección': str
                                                                           })

# %%
# Instancia del objeto
IC = ImportClass()

# %%
# Definición de variables por año
df_estadistica_idc_2015 = IC.df_estadistica_idc_2015
df_delitos_electorales_spoa_2015_2015_2019 = IC.df_delitos_electorales_spoa_2011_2015_2019
df_trashumancia_2015 = IC.df_trashumancia_2015
df_divipole_autoridades_locales_2015 = IC.df_divipole_autoridades_locales_2015

# %%
# Cambiar el nombre de la columna 'nombre_anterior' a 'nombre_nuevo'
df_estadistica_idc_2015.rename(columns = {
    'dd'           : 'cod_dep',
    'mm'           : 'cod_mun',
    'Departamento' : 'departament',
    'Municipio'    : 'municipality',
    'Total'        : 'total',
},inplace=True)

# %%
# Cambiar el nombre de la columna 'nombre_anterior' a 'nombre_nuevo'
df_trashumancia_2015.rename(columns = {
    'Orden'           : 'order',
    'Departamento'    : 'departament',
    'Municipio'       : 'municipality',
    'Trashumantes'    : 'transhumants',
},inplace=True)

# %%
# Cambiar el nombre de la columna 'nombre_anterior' a 'nombre_nuevo'
df_divipole_autoridades_locales_2015.rename(columns = {
    'dd'           : 'cod_dep',
    'mm'           : 'cod_mun',
    'zz'           : '',
    'pp'           : '',
    'Departamento' : 'departament',
    'Municipio'    : 'municipality',
    'Puesto'       : 'position',
    'Mujeres'      : 'women',
    'Hombres'      : 'men',
    'Total'        : 'total',
    'Mesas'        : 'tables',
    'Dirección'    : 'address',
},inplace=True)

# %%
df_estadistica_idc_2015
# Out:
#      cod_dep cod_mun departament    municipality   total
# 0         01     001   ANTIOQUIA        MEDELLIN  125202
# 1         01     004   ANTIOQUIA       ABEJORRAL     983
# 2         01     007   ANTIOQUIA        ABRIAQUI     217
# 3         01     010   ANTIOQUIA      ALEJANDRIA     751
# 4         01     013   ANTIOQUIA           AMAGA    1982
# ...      ...     ...         ...             ...     ...
# 1117      68     022      VAUPES        YAVARATE     169
# 1118      72     001     VICHADA  PUERTO CARREÑO    2891
# 1119      72     002     VICHADA   SANTA ROSALIA     819
# 1120      72     006     VICHADA        CUMARIBO    2491
# 1121      72     008     VICHADA    LA PRIMAVERA    1221
#
# [1122 rows x 5 columns]

# %%
df_delitos_electorales_spoa_2015_2015_2019
# Out:
#                                                  DELITO CRIMINALIDAD  \
# 0     FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.           NO
# 1     DELITOS CONTRA MECANISMOS DE PARTICIPACION DEM...           NO
# 2          CONSTRE√ëIMIENTO AL SUFRAGANTE ART. 387 C.P.           SI
# 3     FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.           SI
# 4          CONSTRE√ëIMIENTO AL SUFRAGANTE ART. 387 C.P.           SI
# ...                                                 ...          ...
# 6610             CORRUPCION DE SUFRAGANTE ART. 390 C.P.           SI
# 6611  ALTERACION DE RESULTADOS ELECTORALES ART. 394 ...           SI
# 6612             CORRUPCION DE SUFRAGANTE ART. 390 C.P.           NO
# 6613  FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.           SI
# 6614                      VOTO FRAUDULENTO ART. 391 C.P           SI
#
#      ES_ARCHIVO ES_PRECLUSI√ìN    ESTADO   ETAPA_CASO      LEY  \
# 0            SI             NO  INACTIVO  INDAGACI√ìN  Ley 906
# ...

# %%
df_trashumancia_2015
# Out:
#      order departament    municipality  transhumants
# 0        1    Amazonas         Leticia           884
# 1        2    Amazonas  Puerto Nariño            201
# 2        3   Antioquia       abejorral           462
# 3        4   Antioquia        abriaqui           107
# 4        5   Antioquia      alejandria           464
# ...    ...         ...             ...           ...
# 1096  1098      Vaupes         taraira           302
# 1097  1099     Vichada        cumaribo          1421
# 1098  1100     Vichada    la primavera           780
# 1099  1101     Vichada  puerto carreño          1744
# 1100  1102     Vichada   santa rosalia           643
#
# [1101 rows x 4 columns]

# %%
# Obtener las columnas de texto
columns_text = df_trashumancia_2015.select_dtypes(include='object').columns

# Convertir todas las columnas de texto a mayúsculas
df_trashumancia_2015[columns_text] = df_trashumancia_2015[columns_text].applymap(str.upper)
df_trashumancia_2015
# Out:
#      order departament    municipality  transhumants
# 0        1    AMAZONAS         LETICIA           884
# 1        2    AMAZONAS  PUERTO NARIÑO            201
# 2        3   ANTIOQUIA       ABEJORRAL           462
# 3        4   ANTIOQUIA        ABRIAQUI           107
# 4        5   ANTIOQUIA      ALEJANDRIA           464
# ...    ...         ...             ...           ...
# 1096  1098      VAUPES         TARAIRA           302
# 1097  1099     VICHADA        CUMARIBO          1421
# 1098  1100     VICHADA    LA PRIMAVERA           780
# 1099  1101     VICHADA  PUERTO CARREÑO          1744
# 1100  1102     VICHADA   SANTA ROSALIA           643
#
# [1101 rows x 4 columns]

# %%
df_divipole_autoridades_locales_2015
# Out:
#       cod_dep cod_mun         departament  municipality  \
# 0          01     001  01  01   ANTIOQUIA      MEDELLIN
# 1          01     001  01  02   ANTIOQUIA      MEDELLIN
# 2          01     001  01  03   ANTIOQUIA      MEDELLIN
# 3          01     001  01  04   ANTIOQUIA      MEDELLIN
# 4          01     001  01  05   ANTIOQUIA      MEDELLIN
# ...       ...     ...  ..  ..         ...           ...
# 10829      72     008  99  70     VICHADA  LA PRIMAVERA
# 10830      72     008  99  80     VICHADA  LA PRIMAVERA
# 10831      72     008  99  82     VICHADA  LA PRIMAVERA
# 10832      72     008  99  90     VICHADA  LA PRIMAVERA
# 10833      72     008  99  92     VICHADA  LA PRIMAVERA
#
#                         position  women   men  total  tables  \
# 0      SEC.ESC.LA ESPERANZA No 2   4120  6877  10997      32
# 1       INST.EDUC. LA CANDELARIA  11202  6077  17279      49
# 2      INST.EDUC.MARIA DE LOS A.   3430  2709   6139      18
# ...

# %%
# Obtener las columnas de texto
columns_text = ['departament', 'municipality', 'position', 'address']

# Convertir todas las columnas de texto a mayúsculas
for column in columns_text:
    if df_divipole_autoridades_locales_2015[column].dtype == 'object':
        df_divipole_autoridades_locales_2015[column] = df_divipole_autoridades_locales_2015[column].str.upper()

# %%
df_divipole_autoridades_locales_2015
# Out:
#       cod_dep cod_mun         departament  municipality  \
# 0          01     001  01  01   ANTIOQUIA      MEDELLIN
# 1          01     001  01  02   ANTIOQUIA      MEDELLIN
# 2          01     001  01  03   ANTIOQUIA      MEDELLIN
# 3          01     001  01  04   ANTIOQUIA      MEDELLIN
# 4          01     001  01  05   ANTIOQUIA      MEDELLIN
# ...       ...     ...  ..  ..         ...           ...
# 10829      72     008  99  70     VICHADA  LA PRIMAVERA
# 10830      72     008  99  80     VICHADA  LA PRIMAVERA
# 10831      72     008  99  82     VICHADA  LA PRIMAVERA
# 10832      72     008  99  90     VICHADA  LA PRIMAVERA
# 10833      72     008  99  92     VICHADA  LA PRIMAVERA
#
#                         position  women   men  total  tables  \
# 0      SEC.ESC.LA ESPERANZA NO 2   4120  6877  10997      32
# 1       INST.EDUC. LA CANDELARIA  11202  6077  17279      49
# 2      INST.EDUC.MARIA DE LOS A.   3430  2709   6139      18
# ...

# %%
df_dep_mun = df_divipole_autoridades_locales_2015[['cod_dep', 'cod_mun', 'departament', 'municipality']]

# %%
df_dep_mun = df_dep_mun.drop_duplicates(subset=['departament', 'municipality']).reset_index().drop(['index'], axis=1)
df_dep_mun
# Out:
#      cod_dep cod_mun departament    municipality
# 0         01     001   ANTIOQUIA        MEDELLIN
# 1         01     004   ANTIOQUIA       ABEJORRAL
# 2         01     007   ANTIOQUIA        ABRIAQUI
# 3         01     010   ANTIOQUIA      ALEJANDRIA
# 4         01     013   ANTIOQUIA           AMAGA
# ...      ...     ...         ...             ...
# 1117      68     022      VAUPES        YAVARATE
# 1118      72     001     VICHADA  PUERTO CARREÑO
# 1119      72     002     VICHADA   SANTA ROSALIA
# 1120      72     006     VICHADA        CUMARIBO
# 1121      72     008     VICHADA    LA PRIMAVERA
#
# [1122 rows x 4 columns]

# %%
# Obtener las columnas de texto
columns_text = df_delitos_electorales_spoa_2015_2015_2019.select_dtypes(include='object').columns

# Convertir todas las columnas de texto a mayúsculas
df_delitos_electorales_spoa_2015_2015_2019[columns_text] = df_delitos_electorales_spoa_2015_2015_2019[columns_text].applymap(str.upper)

# %%
# Usar groupby para agrupar por 'Departamento' y 'Municipio' y luego sumar 'Mujeres'
total_women = df_divipole_autoridades_locales_2015.groupby(['departament', 'municipality'])['women'].sum().reset_index()
total_men = df_divipole_autoridades_locales_2015.groupby(['departament', 'municipality'])['men'].sum().reset_index()
total_people = df_divipole_autoridades_locales_2015.groupby(['departament', 'municipality'])['total'].sum().reset_index()

# %%
total_women
# Out:
#      departament    municipality  women
# 0       AMAZONAS      EL ENCANTO    328
# 1       AMAZONAS     LA CHORRERA    452
# 2       AMAZONAS      LA PEDRERA    428
# 3       AMAZONAS     LA VICTORIA      4
# 4       AMAZONAS         LETICIA  16698
# ...          ...             ...    ...
# 1117      VAUPES        YAVARATE    435
# 1118     VICHADA        CUMARIBO   8299
# 1119     VICHADA    LA PRIMAVERA   3158
# 1120     VICHADA  PUERTO CARREÑO   8058
# 1121     VICHADA   SANTA ROSALIA   1360
#
# [1122 rows x 3 columns]

# %%
total_men
# Out:
#      departament    municipality    men
# 0       AMAZONAS      EL ENCANTO    420
# 1       AMAZONAS     LA CHORRERA    586
# 2       AMAZONAS      LA PEDRERA    590
# 3       AMAZONAS     LA VICTORIA     15
# 4       AMAZONAS         LETICIA  16999
# ...          ...             ...    ...
# 1117      VAUPES        YAVARATE    606
# 1118     VICHADA        CUMARIBO  10884
# 1119     VICHADA    LA PRIMAVERA   3996
# 1120     VICHADA  PUERTO CARREÑO   8948
# 1121     VICHADA   SANTA ROSALIA   1599
#
# [1122 rows x 3 columns]

# %%
total_people
# Out:
#      departament    municipality  total
# 0       AMAZONAS      EL ENCANTO    748
# 1       AMAZONAS     LA CHORRERA   1038
# 2       AMAZONAS      LA PEDRERA   1018
# 3       AMAZONAS     LA VICTORIA     19
# 4       AMAZONAS         LETICIA  33697
# ...          ...             ...    ...
# 1117      VAUPES        YAVARATE   1041
# 1118     VICHADA        CUMARIBO  19183
# 1119     VICHADA    LA PRIMAVERA   7154
# 1120     VICHADA  PUERTO CARREÑO  17006
# 1121     VICHADA   SANTA ROSALIA   2959
#
# [1122 rows x 3 columns]

# %%
df_delitos_electorales_spoa_2015_2015_2019
# Out:
#                                                  DELITO CRIMINALIDAD  \
# 0     FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.           NO
# 1     DELITOS CONTRA MECANISMOS DE PARTICIPACION DEM...           NO
# 2          CONSTRE√ËIMIENTO AL SUFRAGANTE ART. 387 C.P.           SI
# 3     FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.           SI
# 4          CONSTRE√ËIMIENTO AL SUFRAGANTE ART. 387 C.P.           SI
# ...                                                 ...          ...
# 6610             CORRUPCION DE SUFRAGANTE ART. 390 C.P.           SI
# 6611  ALTERACION DE RESULTADOS ELECTORALES ART. 394 ...           SI
# 6612             CORRUPCION DE SUFRAGANTE ART. 390 C.P.           NO
# 6613  FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.           SI
# 6614                      VOTO FRAUDULENTO ART. 391 C.P           SI
#
#      ES_ARCHIVO ES_PRECLUSI√ìN    ESTADO   ETAPA_CASO      LEY  \
# 0            SI             NO  INACTIVO  INDAGACI√ÌN  LEY 906
# ...

# %%
def replace_characters(text):
#       dictionary_replacement = {
#           '√Å': 'Á',
#           '√°': 'Á',
#           '√â': 'É',
#           '√©': 'É',
#           '√Â': 'É',
#           '√≠': 'Í',
#           '√Ç': 'Í',
#           '√Ì': 'Ó',
#           '√≥': 'Ó',
#           '√ì': 'Ó',
#           '√ö': 'Ú',
#           '√Ö': 'Ú',
#           '√±': 'Ñ',
#           '√Ë': 'Ñ',
#       }

      dictionary_replacement = {
          '√Å': 'A',
          '√°': 'A',
          '√â': 'E',
          '√©': 'E',
          '√Â': 'E',
          '√≠': 'I',
          '√Ç': 'I',
          '√Ì': 'O',
          '√≥': 'O',
          '√ì': 'O',
          '√ö': 'U',
          '√Ö': 'U',
          '√±': 'Ñ',
          '√Ë': 'Ñ',
      }
    
      for char, replacement in dictionary_replacement.items():
            text = text.replace(char, replacement)
    
      return text

# %%
# Lista de columnas a las que se aplicará la función
columns = ['DELITO', 'CRIMINALIDAD', 'ES_ARCHIVO', 'ES_PRECLUSI√ìN', 'ESTADO', 'ETAPA_CASO', 'LEY', 'DEPARTAMENTO_HECHO', 'MUNICIPIO_HECHO']

# Aplicar la función a las columnas
df_delitos_electorales_spoa_2015_2015_2019[columns] = df_delitos_electorales_spoa_2015_2015_2019[columns].applymap(replace_characters)

# %%
df_delitos_electorales_spoa_2015_2015_2019
# Out:
#                                                  DELITO CRIMINALIDAD  \
# 0     FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.           NO
# 1     DELITOS CONTRA MECANISMOS DE PARTICIPACION DEM...           NO
# 2           CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.           SI
# 3     FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.           SI
# 4           CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.           SI
# ...                                                 ...          ...
# 6610             CORRUPCION DE SUFRAGANTE ART. 390 C.P.           SI
# 6611  ALTERACION DE RESULTADOS ELECTORALES ART. 394 ...           SI
# 6612             CORRUPCION DE SUFRAGANTE ART. 390 C.P.           NO
# 6613  FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.           SI
# 6614                      VOTO FRAUDULENTO ART. 391 C.P           SI
#
#      ES_ARCHIVO ES_PRECLUSI√ìN    ESTADO  ETAPA_CASO      LEY  \
# 0            SI             NO  INACTIVO  INDAGACION  LEY 906
# ...

# %%
df_2015 = df_delitos_electorales_spoa_2015_2015_2019['AÑO_HECHOS'] == 2015

# %%
df_delitos_electorales_spoa_2015 = df_delitos_electorales_spoa_2015_2015_2019[df_2015]

# %%
df_delitos_electorales_spoa_2015.reset_index().drop(['index'], axis=1)
# Out:
#                                                  DELITO CRIMINALIDAD  \
# 0           CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.           SI
# 1                    FRAUDE AL SUFRAGANTE ART. 388 C.P.           SI
# 2           CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.           NO
# 3     OCULTAMIENTO, RETENCION Y POSESION ILICITA DE ...           SI
# 4           CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.           SI
# ...                                                 ...          ...
# 2093  FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.           NO
# 2094             CORRUPCION DE SUFRAGANTE ART. 390 C.P.           NO
# 2095             INTERVENCION EN POLITICA ART. 422 C.P.           SI
# 2096  FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.           SI
# 2097  FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.           SI
#
#      ES_ARCHIVO ES_PRECLUSI√ìN    ESTADO  ETAPA_CASO      LEY  \
# 0            NO             NO    ACTIVO  INDAGACION  LEY 906
# ...

# %%
# Cambiar el nombre de la columna 'nombre_anterior' a 'nombre_nuevo'
df_delitos_electorales_spoa_2015.rename(columns = {
    'DELITO'             : 'crime',
    'CRIMINALIDAD'       : 'criminality',
    'ES_ARCHIVO'         : 'is_file',
    'ES_PRECLUSI√ìN'     : 'is_preclusion',
    'ESTADO'             : 'state',
    'ETAPA_CASO'         : 'state_case',
    'LEY'                : 'law',
    'DEPARTAMENTO_HECHO' : 'departament',
    'MUNICIPIO_HECHO'    : 'municipality',
    'AÑO_HECHOS'         : 'year',
    'TOTAL_PROCESOS'     : 'total_processes',
},inplace=True)
# Out:
# C:\Users\hysanchez\AppData\Local\Temp\ipykernel_9084\3519856683.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_delitos_electorales_spoa_2015.rename(columns = {

# %%
df_estadistica_idc_2015.to_csv("2015/df_estadistica_idc_2015.csv")
df_delitos_electorales_spoa_2015.to_csv("2015/df_delitos_electorales_spoa_2015.csv")

# %%
df_2015 = df_delitos_electorales_spoa_2015.reset_index().drop(['index'], axis=1).copy()

# %%
# Crear un diccionario de mapeo de departamentos y valores a partir de df_estadistica_idc_2015
departamentos_valores = dict(zip(df_estadistica_idc_2015['departament'], df_estadistica_idc_2015['cod_dep']))

# Define una función para aplicar la condición utilizando el diccionario
def asignar_valor(row):
    departamento = row['departament']
    return departamentos_valores.get(departamento, None)  # Devuelve el valor correspondiente o None si no se encuentra

# Aplica la función a cada fila del DataFrame y crea la nueva columna
df_2015['cod_dep'] = df_2015.apply(asignar_valor, axis=1)

# %%
df_2015
# Out:
#                                                   crime criminality is_file  \
# 0           CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.          SI      NO
# 1                    FRAUDE AL SUFRAGANTE ART. 388 C.P.          SI      NO
# 2           CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.          NO      SI
# 3     OCULTAMIENTO, RETENCION Y POSESION ILICITA DE ...          SI      NO
# 4           CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.          SI      SI
# ...                                                 ...         ...     ...
# 2093  FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.          NO      SI
# 2094             CORRUPCION DE SUFRAGANTE ART. 390 C.P.          NO      SI
# 2095             INTERVENCION EN POLITICA ART. 422 C.P.          SI      NO
# 2096  FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.          SI      NO
# 2097  FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.          SI      NO
#
# ...

# %%
# Crear un diccionario de mapeo de departamentos y valores a partir de df_estadistica_idc_2015
municipality_valores = dict(zip(df_estadistica_idc_2015['municipality'], df_estadistica_idc_2015['cod_mun']))

# Define una función para aplicar la condición utilizando el diccionario
def asignar_valor(row):
    municipality = row['municipality']
    return municipality_valores.get(municipality, None)  # Devuelve el valor correspondiente o None si no se encuentra

# Aplica la función a cada fila del DataFrame y crea la nueva columna
df_2015['cod_mun'] = df_2015.apply(asignar_valor, axis=1)

# %%
# Crear un diccionario de mapeo de departamentos y valores a partir de df_estadistica_idc_2015
municipality_valores = dict(zip(df_estadistica_idc_2015['municipality'], df_estadistica_idc_2015['total']))

# Define una función para aplicar la condición utilizando el diccionario
def asignar_valor(row):
    municipality = row['municipality']
    return municipality_valores.get(municipality, None)  # Devuelve el valor correspondiente o None si no se encuentra

# Aplica la función a cada fila del DataFrame y crea la nueva columna
df_2015['total_idc'] = df_2015.apply(asignar_valor, axis=1)

# %%
# Crear un diccionario de mapeo de departamentos y valores a partir de df_estadistica_idc_2015
trashumancia_valores = dict(zip(df_trashumancia_2015['municipality'], df_trashumancia_2015['transhumants']))

# Define una función para aplicar la condición utilizando el diccionario
def asignar_valor(row):
    transhumants = row['municipality']
    return trashumancia_valores.get(transhumants, 0)  # Devuelve el valor correspondiente o None si no se encuentra

# Aplica la función a cada fila del DataFrame y crea la nueva columna
df_2015['transhumants'] = df_2015.apply(asignar_valor, axis=1)

# %%
# Crear un diccionario de mapeo de departamentos y valores a partir de df_estadistica_idc_2015
women_valores = dict(zip(total_women['municipality'], total_women['women']))

# Define una función para aplicar la condición utilizando el diccionario
def asignar_valor(row):
    women = row['municipality']
    return women_valores.get(women, None)  # Devuelve el valor correspondiente o None si no se encuentra

# Aplica la función a cada fila del DataFrame y crea la nueva columna
df_2015['total_women'] = df_2015.apply(asignar_valor, axis=1)

# %%
# Crear un diccionario de mapeo de departamentos y valores a partir de df_estadistica_idc_2015
men_valores = dict(zip(total_men['municipality'], total_men['men']))

# Define una función para aplicar la condición utilizando el diccionario
def asignar_valor(row):
    men = row['municipality']
    return men_valores.get(men, None)  # Devuelve el valor correspondiente o None si no se encuentra

# Aplica la función a cada fila del DataFrame y crea la nueva columna
df_2015['total_men'] = df_2015.apply(asignar_valor, axis=1)

# %%
# Crear un diccionario de mapeo de departamentos y valores a partir de df_estadistica_idc_2015
valores = dict(zip(total_people['municipality'], total_people['total']))

# Define una función para aplicar la condición utilizando el diccionario
def asignar_valor(row):
    men = row['municipality']
    return valores.get(men, None)  # Devuelve el valor correspondiente o None si no se encuentra

# Aplica la función a cada fila del DataFrame y crea la nueva columna
df_2015['total_people'] = df_2015.apply(asignar_valor, axis=1)

# %%
df_2015
# Out:
#                                                   crime criminality is_file  \
# 0           CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.          SI      NO
# 1                    FRAUDE AL SUFRAGANTE ART. 388 C.P.          SI      NO
# 2           CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.          NO      SI
# 3     OCULTAMIENTO, RETENCION Y POSESION ILICITA DE ...          SI      NO
# 4           CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.          SI      SI
# ...                                                 ...         ...     ...
# 2093  FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.          NO      SI
# 2094             CORRUPCION DE SUFRAGANTE ART. 390 C.P.          NO      SI
# 2095             INTERVENCION EN POLITICA ART. 422 C.P.          SI      NO
# 2096  FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.          SI      NO
# 2097  FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.          SI      NO
#
# ...

# %%
df_2015.sort_values(by=['cod_dep', 'cod_mun'], ascending=[True, True]).reset_index().drop(['index'], axis=1)
# Out:
#                                                   crime criminality is_file  \
# 0     PERTURBACION DE CERTAMEN DEMOCRATICO ART. 386 ...          SI      SI
# 1                CORRUPCION DE SUFRAGANTE ART. 390 C.P.          SI      SI
# 2                CORRUPCION DE SUFRAGANTE ART. 390 C.P.          SI      NO
# 3           CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.          SI      NO
# 4     PERTURBACION DE CERTAMEN DEMOCRATICO ART. 386 ...          SI      NO
# ...                                                 ...         ...     ...
# 2093             CORRUPCION DE SUFRAGANTE ART. 390 C.P.          NO      SI
# 2094             CORRUPCION DE SUFRAGANTE ART. 390 C.P.          SI      NO
# 2095        CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.          NO      SI
# 2096  FRAUDE EN LA INSCRIPCION DE CEDULAS ART. 389 C.P.          SI      NO
# 2097        CONSTREÑIMIENTO AL SUFRAGANTE ART. 387 C.P.          NO      SI
#
# ...

# %%
# Supongamos que tienes un DataFrame df con columnas originales
# y deseas reordenarlas en un nuevo orden específico
new_order = [
    'year',
    'cod_dep',
    'departament',
    'cod_mun',
    'municipality',
    'crime',
    'criminality',
    'is_file',
    'is_preclusion',
    'state',
    'state_case',
    'law',
    'total_processes',
    'transhumants',
    'total_idc',
    'total_women',
    'total_men',
    'total_people'
]

# Utiliza .reorder_levels() para cambiar el orden de las columnas
df_2015 = df_2015[new_order].sort_values(by=['cod_dep', 'cod_mun'], ascending=[True, True]).reset_index().drop(['index'], axis=1)

# %%
df_2015
# Out:
#       year cod_dep departament cod_mun    municipality  \
# 0     2015      01   ANTIOQUIA     001        MEDELLIN
# 1     2015      01   ANTIOQUIA     001        MEDELLIN
# 2     2015      01   ANTIOQUIA     001        MEDELLIN
# 3     2015      01   ANTIOQUIA     001        MEDELLIN
# 4     2015      01   ANTIOQUIA     001        MEDELLIN
# ...    ...     ...         ...     ...             ...
# 2093  2015      68      VAUPES     001            MITU
# 2094  2015      68      VAUPES     001            MITU
# 2095  2015      68      VAUPES     001            MITU
# 2096  2015      68      VAUPES     001            MITU
# 2097  2015      72     VICHADA     001  PUERTO CARREÑO
#
#                                                   crime criminality is_file  \
# 0     PERTURBACION DE CERTAMEN DEMOCRATICO ART. 386 ...          SI      SI
# 1                CORRUPCION DE SUFRAGANTE ART. 390 C.P.          SI      SI
# ...

# %%
df_dep_mun
# Out:
#      cod_dep cod_mun departament    municipality
# 0         01     001   ANTIOQUIA        MEDELLIN
# 1         01     004   ANTIOQUIA       ABEJORRAL
# 2         01     007   ANTIOQUIA        ABRIAQUI
# 3         01     010   ANTIOQUIA      ALEJANDRIA
# 4         01     013   ANTIOQUIA           AMAGA
# ...      ...     ...         ...             ...
# 1117      68     022      VAUPES        YAVARATE
# 1118      72     001     VICHADA  PUERTO CARREÑO
# 1119      72     002     VICHADA   SANTA ROSALIA
# 1120      72     006     VICHADA        CUMARIBO
# 1121      72     008     VICHADA    LA PRIMAVERA
#
# [1122 rows x 4 columns]

# %%
# Crear un DataFrame vacío para almacenar los resultados
df_consolidated_2015 = pd.DataFrame(columns=df_dep_mun.columns)

# Iterar a través de las filas de df_dep_mun
for _, fila in df_dep_mun.iterrows():
    municipio = fila['municipality']
    # Buscar el municipio correspondiente en df_2015
    filtro = df_2015['municipality'] == municipio
    datos_municipio = df_2015[filtro]
    
    if not datos_municipio.empty:
        # Si se encuentra el municipio en df_2015, agregamos las filas correspondientes
        df_consolidated_2015 = pd.concat([df_consolidated_2015, datos_municipio], ignore_index=True)
    else:
        # Si no se encuentra el municipio en df_2015, agregamos una fila vacía
        df_consolidated_2015 = pd.concat([df_consolidated_2015, fila.to_frame().T], ignore_index=True)

# Ahora, df_consolidated_2015 contiene los datos combinados

# %%
df_consolidated_2015
# Out:
#      cod_dep cod_mun departament    municipality    year  \
# 0         01     001   ANTIOQUIA        MEDELLIN  2015.0
# 1         01     001   ANTIOQUIA        MEDELLIN  2015.0
# 2         01     001   ANTIOQUIA        MEDELLIN  2015.0
# 3         01     001   ANTIOQUIA        MEDELLIN  2015.0
# 4         01     001   ANTIOQUIA        MEDELLIN  2015.0
# ...      ...     ...         ...             ...     ...
# 2683      68     022      VAUPES        YAVARATE     NaN
# 2684      72     001     VICHADA  PUERTO CARREÑO  2015.0
# 2685      72     002     VICHADA   SANTA ROSALIA     NaN
# 2686      72     006     VICHADA        CUMARIBO     NaN
# 2687      72     008     VICHADA    LA PRIMAVERA     NaN
#
#                                                   crime criminality is_file  \
# 0     PERTURBACION DE CERTAMEN DEMOCRATICO ART. 386 ...          SI      SI
# 1                CORRUPCION DE SUFRAGANTE ART. 390 C.P.          SI      SI
# ...

# %%
df_consolidated_2015['year'] = '2015'
columnas_para_reemplazar = ['crime', 'criminality', 'is_file', 'is_preclusion', 'state', 'state_case', 'law']

for columna in columnas_para_reemplazar:
    df_consolidated_2015[columna] = df_consolidated_2015[columna].fillna('SIN REGISTRO')

# %%
columnas_para_reemplazar_int = ['total_processes', 'transhumants', 'total_idc', 'total_women', 'total_men', 'total_people']

for columna in columnas_para_reemplazar_int:
    df_consolidated_2015[columna] = df_consolidated_2015[columna].fillna(0)

# %%
df_consolidated_2015
# Out:
#      cod_dep cod_mun departament    municipality  year  \
# 0         01     001   ANTIOQUIA        MEDELLIN  2015
# 1         01     001   ANTIOQUIA        MEDELLIN  2015
# 2         01     001   ANTIOQUIA        MEDELLIN  2015
# 3         01     001   ANTIOQUIA        MEDELLIN  2015
# 4         01     001   ANTIOQUIA        MEDELLIN  2015
# ...      ...     ...         ...             ...   ...
# 2683      68     022      VAUPES        YAVARATE  2015
# 2684      72     001     VICHADA  PUERTO CARREÑO  2015
# 2685      72     002     VICHADA   SANTA ROSALIA  2015
# 2686      72     006     VICHADA        CUMARIBO  2015
# 2687      72     008     VICHADA    LA PRIMAVERA  2015
#
#                                                   crime   criminality  \
# 0     PERTURBACION DE CERTAMEN DEMOCRATICO ART. 386 ...            SI
# 1                CORRUPCION DE SUFRAGANTE ART. 390 C.P.            SI
# 2                CORRUPCION DE SUFRAGANTE ART. 390 C.P.            SI
# ...

# %%
# Cambiar el nombre de la columna 'nombre_anterior' a 'nombre_nuevo'
df_consolidated_2015.rename(columns = {
    'cod_dep'         : 'COD_DEP',
    'cod_mun'         : 'COD_MUN',
    'departament'     : 'DEPARTAMENTO',
    'municipality'    : 'MUNICIPIO',
    'year'            : 'AÑO',
    'crime'           : 'DELITO',
    'criminality'     : 'CRIMINALIDAD',
    'is_file'         : 'ES_ARCHIVO',
    'is_preclusion'   : 'ES_PRECLUSIÓN',
    'state'           : 'ESTADO',
    'state_case'      : 'ETAPA_CASO',
    'law'             : 'LEY',
    'total_processes' : 'TOTAL_PROCESOS',
    'transhumants'    : 'TRANSHUMANTES',
    'total_idc'       : 'IDC_TOTAL',
    'total_women'     : 'MUJERES_DIVIPOLE',
    'total_men'       : 'HOMBRES_DIVIPOLE',
    'total_people'    : 'TOTAL_DIVIPOLE',
},inplace=True)

# %%
# Define el tipo de datos de múltiples columnas al mismo tiempo
columnas_para_convertir = [
    'COD_DEP',
    'COD_MUN',
    'DEPARTAMENTO',
    'MUNICIPIO',
    'AÑO',
    'DELITO',
    'CRIMINALIDAD',
    'ES_ARCHIVO',
    'ES_PRECLUSIÓN',
    'ESTADO',
    'ETAPA_CASO',
    'LEY'
]

# Utiliza el método astype para convertir estas columnas al tipo deseado
df_consolidated_2015[columnas_para_convertir] = df_consolidated_2015[columnas_para_convertir].astype(str)

# %%
df_consolidated_2015.to_csv("2015/consolidated_2015.csv", index=False)

# %%
df_consolidated_2015_clean = df_consolidated_2015[df_consolidated_2015['DELITO'] != 'SIN REGISTRO']

# %%
df_consolidated_2015_clean = df_consolidated_2015_clean.reset_index().drop(['index'], axis=1)
df_consolidated_2015_clean
# Out:
#      COD_DEP COD_MUN DEPARTAMENTO       MUNICIPIO   AÑO  \
# 0         01     001    ANTIOQUIA        MEDELLIN  2015
# 1         01     001    ANTIOQUIA        MEDELLIN  2015
# 2         01     001    ANTIOQUIA        MEDELLIN  2015
# 3         01     001    ANTIOQUIA        MEDELLIN  2015
# 4         01     001    ANTIOQUIA        MEDELLIN  2015
# ...      ...     ...          ...             ...   ...
# 2287      68     001       VAUPES            MITU  2015
# 2288      68     001       VAUPES            MITU  2015
# 2289      68     001       VAUPES            MITU  2015
# 2290      68     001       VAUPES            MITU  2015
# 2291      72     001      VICHADA  PUERTO CARREÑO  2015
#
#                                                  DELITO CRIMINALIDAD  \
# 0     PERTURBACION DE CERTAMEN DEMOCRATICO ART. 386 ...           SI
# 1                CORRUPCION DE SUFRAGANTE ART. 390 C.P.           SI
# 2                CORRUPCION DE SUFRAGANTE ART. 390 C.P.           SI
# ...

# %%
df_consolidated_2015_clean.to_csv("2015/consolidated_2015_clean.csv", index=False)
